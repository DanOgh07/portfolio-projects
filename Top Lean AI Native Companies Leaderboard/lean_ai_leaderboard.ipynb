# %% [markdown]
# #

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
import numpy as np
from bs4 import BeautifulSoup
import requests
import time
import datetime
import csv
import ssl

# %%
ssl._create_default_https_context = ssl._create_unverified_context

URL = "https://leanaileaderboard.com"

scraper = pd.read_html(URL)

scraper
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       1 ssl._create_default_https_context = ssl._create_unverified_context
#       2
#       3 URL = "https://leanaileaderboard.com"
#       4
# ----> 5 scraper = pd.read_html(URL)
#       6
#       7 scraper
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)   1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
# ...

# %%
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')
soup = BeautifulSoup(soup.prettify())

title = soup.find('iframe', {'class': 'text-lg sm:text-xl font-semibold'}).get_text(strip=True)

print(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 5
#       1 page = requests.get(URL)
#       2 soup = BeautifulSoup(page.content, 'html.parser')
#       3 soup = BeautifulSoup(soup.prettify())
#       4
# ----> 5 title = soup.find('iframe', {'class': 'text-lg sm:text-xl font-semibold'}).get_text(strip=True)
#       6
#       7 print(title)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
table = soup.find('h1', {'class': 'table-iframe'}).get_text(strip=True)

print(table)

# %%
# src="https://docs.google.com/spreadsheets/d/e/2PACX-1vQ1vMlwTJ8_Lty161T73uwnMzVxb48XzHxz9aPNla5OgCjd2yJ0HMfxEHGSv1OsyGOarWUYDcsJZfmk/pubhtml?widget=true&amp;headers=false" 

SHEET_ID = "2PACX-1vQ1vMlwTJ8_Lty161T73uwnMzVxb48XzHxz9aPNla5OgCjd2yJ0HMfxEHGSv1OsyGOarWUYDcsJZfmk"
CSV_URL = f"https://docs.google.com/spreadsheets/d/e/{SHEET_ID}/pub?output=csv"

df = pd.read_csv(CSV_URL)
print(df)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Python313\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File c:\Python313\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Python313\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
def leaderboard_check():
    URL = "https://leanaileaderboard.com"


    page = requests.get(URL)

    soup = BeautifulSoup(page.content, "html.parser")
    soup = BeautifulSoup(soup.prettify())

    title = soup.find(id='productTitle').get_text(strip=True)

    price = soup.find('span', {'class': 'a-price'}).get_text(strip=True)
    price = price[3:]

    today = datetime.date.today()

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScrData.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
# Create figure and axis
fig, ax = plt.subplots(figsize=(12, 8))  # Adjust size for better spacing

# Create vertical bars with a gradient color
colors = plt.cm.Blues(np.linspace(0.3, 1, len(companies)))  # Light to dark blue
bars = ax.bar(companies, revenue_per_employee, color=colors)

# Set labels and title
ax.set_xlabel('Company')
ax.set_ylabel('Revenue per Employee (Millions of Dollars)')

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45, ha='right')

# Add data labels on top of bars
for bar, value in zip(bars, revenue_per_employee):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.1, 
            f'${value:.2f}M', ha='center', va='bottom', fontsize=10)

# Add logos next to company names on x-axis
for i, company in enumerate(companies):
    try:
        logo = mpimg.imread(f'logos/{company}.png')
        imagebox = OffsetImage(logo, zoom=0.1)  # Increased zoom for visibility
        ab = AnnotationBbox(imagebox, (i, -0.05), frameon=False, pad=0.0,  # Adjusted y-coordinate
                            xycoords='data', boxcoords=("data", "axes fraction"))
        ax.add_artist(ab)
    except FileNotFoundError:
        print(f"Logo not found for {company}")

# Adjust layout and save
plt.tight_layout()
plt.savefig('vertical_bar_chart.png', dpi=300, bbox_inches='tight')  # Save as high-quality image
plt.show()
